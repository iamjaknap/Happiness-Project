# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Importing all the necessay Libraries

# %%
df=pd.read_csv('happiness_score.csv')
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %% [markdown]
# Loading the Happiness Score Data in Dataframe and checking the first five rows

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Shows the Important attributes of Columns such as Mean,Median, Percentile

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# Showing Number of rows and columns in the Dataset. No of Rows=158, Columns=12

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# Shows the information of Dataset like Number of Columns, Number of Datas in Column, Data Type,

# %%
df.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Top 10 Most Happy Country

# %%
df.tail(10)
# Out:
#           Country                           Region  Happiness Rank  \
# 148          Chad               Sub-Saharan Africa             149
# 149        Guinea               Sub-Saharan Africa             150
# 150   Ivory Coast               Sub-Saharan Africa             151
# 151  Burkina Faso               Sub-Saharan Africa             152
# 152   Afghanistan                    Southern Asia             153
# 153        Rwanda               Sub-Saharan Africa             154
# 154         Benin               Sub-Saharan Africa             155
# 155         Syria  Middle East and Northern Africa             156
# 156       Burundi               Sub-Saharan Africa             157
# 157          Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 148            3.667         0.03830                   0.34193  0.76062
# 149            3.656         0.03590                   0.17417  0.46475
# ...

# %% [markdown]
# 10 Least Haapy Countries

# %%
df.keys()
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# Shows The Heading of the Columns as in Datasets

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Checking the Missing Data in the DataSet. There is no Missing Data

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking the Missing Data Using Heat Map. Missing Data is generally shown in white. There is no Missing Data Shown in Heat Map

# %%
sns.stripplot(x='Region',y='Happiness Score',data=df,size=4)
plt.xticks(rotation = 90)
plt.title("Countries' Happiness Score According to the Region", color = 'blue', fontsize = 15)
plt.show()

# %% [markdown]
# PLotting Happiness Score against Region. It shows that Western Europe has Higher Happiness Score and Southern Asia has Lower Happiness Score

# %%
df.groupby('Region').mean().reset_index()
# Out:
#                             Region  Happiness Rank  Happiness Score  \
# 0        Australia and New Zealand        9.500000         7.285000
# 1       Central and Eastern Europe       79.000000         5.332931
# 2                     Eastern Asia       64.500000         5.626167
# 3      Latin America and Caribbean       46.909091         6.144682
# 4  Middle East and Northern Africa       77.600000         5.406900
# 5                    North America       10.000000         7.273000
# 6                Southeastern Asia       81.222222         5.317444
# 7                    Southern Asia      113.142857         4.580857
# 8               Sub-Saharan Africa      127.900000         4.202800
# 9                   Western Europe       29.523810         6.689619
#
#    Standard Error  Economy (GDP per Capita)    Family  \
# 0        0.037270                  1.291880  1.314450
# 1        0.045208                  0.942438  1.053042
# ...

# %% [markdown]
# It Show the Mean of Data arranged Region-wise. It shows Australia and New Zealand has Highest mean and Sub-Saharan Africa has the lowest mean.

# %%
df.groupby('Region').describe()
# Out:
#                                 Happiness Rank                               \
#                                          count        mean        std   min
# Region
# Australia and New Zealand                  2.0    9.500000   0.707107   9.0
# Central and Eastern Europe                29.0   79.000000  26.667262  31.0
# Eastern Asia                               6.0   64.500000  24.688054  38.0
# Latin America and Caribbean               22.0   46.909091  28.716859  12.0
# Middle East and Northern Africa           20.0   77.600000  43.213546  11.0
# North America                              2.0   10.000000   7.071068   5.0
# Southeastern Asia                          9.0   81.222222  39.917971  24.0
# Southern Asia                              7.0  113.142857  26.573349  79.0
# Sub-Saharan Africa                        40.0  127.900000  22.863923  71.0
# Western Europe                            21.0   29.523810  29.268787   1.0
#
# ...

# %% [markdown]
# This Describe the Region-wise Mean, Median, Standard Deviation of the Dataset in Columns

# %%
corhmap=df.corr()
plt.figure(figsize=(8,7))
sns.heatmap(corhmap,annot=True)
plt.show()

# %% [markdown]
# This Show Correlation Heat Map

# %%
plt.xlabel('Economy (GDP per Capita)')
plt.ylabel('Happiness Score')
plt.scatter(df['Economy (GDP per Capita)'],df['Happiness Score'])
plt.show()

# %% [markdown]
# This Scatter Plot shows distribution of data Happiness Score and Economy (GDP per Capita)

# %%
df.astype(bool).sum(axis=0)
# Out:
# Country                          158
# Region                           158
# Happiness Rank                   158
# Happiness Score                  158
# Standard Error                   158
# Economy (GDP per Capita)         157
# Family                           157
# Health (Life Expectancy)         157
# Freedom                          157
# Trust (Government Corruption)    157
# Generosity                       157
# Dystopia Residual                158
# dtype: int64

# %%
(df == 0).astype(bool).sum(axis=0)
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         1
# Family                           1
# Health (Life Expectancy)         1
# Freedom                          1
# Trust (Government Corruption)    1
# Generosity                       1
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# The above two Cells show the number of attributes having Zero Value. It shows six columns having zero value. Since Value cannot be zero so. We can replave this by mean data.

# %%
pd.unique(df['Region'])
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df1=df.replace(0,df.mean())
df1
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %% [markdown]
# Replacing the Zero Value with Mean of Column

# %%
(df1 == 0).astype(bool).sum(axis=0)
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# Checking the Values of Dataframe df1. There is no Zero Value

# %%
df1['Region'].value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# It Show the Count of Countries Region-wise

# %%
sns.pairplot(df1,hue='Region')

# %% [markdown]
# This Pair Plot Shows the Plot of Columns with respect to one another

# %%
sns.barplot(x=df1['Region'],y=df1['Happiness Score'])
plt.xlabel('Region')
plt.xticks(rotation = 90)
plt.ylabel('Happiness Score')
plt.title('Happiness Score According to the Region', color = 'blue', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=[10,10])
plt.title('Comparision between Fmaily and Happines Score')
sns.scatterplot(df1['Family'],df1['Happiness Score'],hue=df1['Region'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Region and Happines Score'}, xlabel='Family', ylabel='Happiness Score'>

# %%
plt.figure(figsize=[10,7])
plt.title('PLot of Economy (GDP per Capita) and Happines Score')
sns.scatterplot(df1['Economy (GDP per Capita)'],df1['Happiness Score'],hue=df1['Region'])
# Out:
# <AxesSubplot:title={'center':'Comparision between Economy (GDP per Capita) and Happines Score'}, xlabel='Economy (GDP per Capita)', ylabel='Happiness Score'>

# %% [markdown]
# Shows the Scatter Plot of Economy (GDP per Capita) and Happines Score

# %%
df1['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Southeastern Asia', 'Central and Eastern Europe', 'Eastern Asia',
#        'Sub-Saharan Africa', 'Southern Asia'], dtype=object)

# %%
df['Happiness Score'].plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# SHows the Probability Density of Happiness Score

# %%
plt.figure(figsize=[25,7])
sns.barplot(x=df1['Country'],y=df1['Health (Life Expectancy)'])
plt.xlabel('Country')
plt.xticks(rotation = 90)
plt.ylabel('Health (Life Expectancy)')
plt.title('Health (Life Expectancy) According to the Country', color = 'blue', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=[25,7])
sns.barplot(x=df1['Country'],y=df1['Family'])
plt.xlabel('Country')
plt.xticks(rotation = 90)
plt.ylabel('Family')
plt.title('Family According to the Country', color = 'blue', fontsize = 20)
plt.show()

# %%
plt.figure(figsize=[25,7])
sns.barplot(x=df1['Country'],y=df1['Freedom'])
plt.xlabel('Country')
plt.xticks(rotation = 90)
plt.ylabel('Freedom')
plt.title('Freedom According to the Country', color = 'blue', fontsize = 20)
plt.show()
